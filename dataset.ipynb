# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("india-districts-census-2011.csv")

# %%
df.head(5)
# Out:
#    District code         State name District name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Male_Literate  Female_Literate    SC  ...  \
# 0    439654         282823           156831  1048  ...
# 1    335649         207741           127908   368  ...
# 2     93770          62834            30936   488  ...
# 3     86236          56301            29935    18  ...
# 4    261724         163333            98391   556  ...
#
#    Power_Parity_Rs_90000_150000  Power_Parity_Rs_45000_150000  \
# 0                            94                           588
# ...

# %%
df.shape
# Out:
# (640, 118)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Columns: 118 entries, District code to Total_Power_Parity
# dtypes: int64(116), object(2)
# memory usage: 590.1+ KB

# %%
df.describe()
# Out:
#        District code    Population          Male        Female      Literate  \
# count     640.000000  6.400000e+02  6.400000e+02  6.400000e+02  6.400000e+02
# mean      320.500000  1.891961e+06  9.738598e+05  9.181011e+05  1.193186e+06
# std       184.896367  1.544380e+06  8.007785e+05  7.449864e+05  1.068583e+06
# min         1.000000  8.004000e+03  4.414000e+03  3.590000e+03  4.436000e+03
# 25%       160.750000  8.178610e+05  4.171682e+05  4.017458e+05  4.825982e+05
# 50%       320.500000  1.557367e+06  7.986815e+05  7.589200e+05  9.573465e+05
# 75%       480.250000  2.583551e+06  1.338604e+06  1.264277e+06  1.602260e+06
# max       640.000000  1.106015e+07  5.865078e+06  5.195070e+06  8.227161e+06
#
#        Male_Literate  Female_Literate            SC       Male_SC  \
# count   6.400000e+02     6.400000e+02  6.400000e+02  6.400000e+02
# mean    6.793182e+05     5.138675e+05  3.146537e+05  1.617739e+05
# std     5.924144e+05     4.801816e+05  3.129818e+05  1.611216e+05
# ...

# %%
df.head(2)
# Out:
#    District code         State name District name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
#
#    Literate  Male_Literate  Female_Literate    SC  ...  \
# 0    439654         282823           156831  1048  ...
# 1    335649         207741           127908   368  ...
#
#    Power_Parity_Rs_90000_150000  Power_Parity_Rs_45000_150000  \
# 0                            94                           588
# 1                           126                           562
#
#    Power_Parity_Rs_150000_240000  Power_Parity_Rs_240000_330000  \
# 0                             71                            101
# 1                             72                             89
#
#    Power_Parity_Rs_150000_330000  Power_Parity_Rs_330000_425000  \
# 0                            172                             74
# ...

# %%
((df.groupby('State name')['Population'].sum() / df['Population'].sum()) * 100).sort_values().plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='State name'>

# %%
df['State name'].unique()
# Out:
# array(['JAMMU AND KASHMIR', 'HIMACHAL PRADESH', 'PUNJAB', 'CHANDIGARH',
#        'UTTARAKHAND', 'HARYANA', 'NCT OF DELHI', 'RAJASTHAN',
#        'UTTAR PRADESH', 'BIHAR', 'SIKKIM', 'ARUNACHAL PRADESH',
#        'NAGALAND', 'MANIPUR', 'MIZORAM', 'TRIPURA', 'MEGHALAYA', 'ASSAM',
#        'WEST BENGAL', 'JHARKHAND', 'ORISSA', 'CHHATTISGARH',
#        'MADHYA PRADESH', 'GUJARAT', 'DAMAN AND DIU',
#        'DADRA AND NAGAR HAVELI', 'MAHARASHTRA', 'ANDHRA PRADESH',
#        'KARNATAKA', 'GOA', 'LAKSHADWEEP', 'KERALA', 'TAMIL NADU',
#        'PONDICHERRY', 'ANDAMAN AND NICOBAR ISLANDS'], dtype=object)

# %%
df.columns
# Out:
# Index(['District code', 'State name', 'District name', 'Population', 'Male',
#        'Female', 'Literate', 'Male_Literate', 'Female_Literate', 'SC',
#        ...
#        'Power_Parity_Rs_90000_150000', 'Power_Parity_Rs_45000_150000',
#        'Power_Parity_Rs_150000_240000', 'Power_Parity_Rs_240000_330000',
#        'Power_Parity_Rs_150000_330000', 'Power_Parity_Rs_330000_425000',
#        'Power_Parity_Rs_425000_545000', 'Power_Parity_Rs_330000_545000',
#        'Power_Parity_Above_Rs_545000', 'Total_Power_Parity'],
#       dtype='object', length=118)

# %%
df2=pd.read_csv('State wise zone .csv')

# %%
df2['State']=df2['State'].str.lower()
df2.head(4)
df2[df2['State']=='andhra pradesh']
# Out:
#             State Vehicle      Zone Established languages[36]
# 0  andhra pradesh      AP  Southern   01-Nov-56        Telugu

# %%
df['State name']=df['State name'].str.lower()

# %%
df3=pd.read_csv('district wise lat nd Long.csv')
df3.head()
# Out:
#           District   Latitude  Longitude
# 0  andaman islands  12.382571  92.822911
# 1  nicobar islands   7.835291  93.511601
# 2         adilabad  19.284514  78.813212
# 3        anantapur  14.312066  77.460158
# 4         chittoor  13.331093  78.927639

# %%
# making new datafrme
df['District name']=df['District name'].str.lower()

# %%
final_df=pd.merge(df,df2,left_on='State name',right_on='State',how='left')

# %%
final_df=pd.merge(final_df,df3,left_on='District name',right_on='District',how='left')

# %%
final_df.head(1)
# Out:
#    District code         State name District name  Population    Male  Female  \
# 0              1  jammu and kashmir       kupwara      870354  474190  396164
#
#    Literate  Male_Literate  Female_Literate    SC  ...  \
# 0    439654         282823           156831  1048  ...
#
#    Power_Parity_Above_Rs_545000  Total_Power_Parity              State  \
# 0                            15                1119  jammu and kashmir
#
#    Vehicle      Zone  Established                          languages[36]  \
# 0       JK  Northern    31-Oct-19  Dogri, English, Hindi, Kashmiri, Urdu
#
#    District  Latitude  Longitude
# 0       NaN       NaN        NaN
#
# [1 rows x 126 columns]

# %%
final_df.describe()
# Out:
#        District code    Population          Male        Female      Literate  \
# count     649.000000  6.490000e+02  6.490000e+02  6.490000e+02  6.490000e+02
# mean      320.345146  1.893023e+06  9.743719e+05  9.186516e+05  1.194513e+06
# std       184.936787  1.538986e+06  7.979734e+05  7.423874e+05  1.064621e+06
# min         1.000000  8.004000e+03  4.414000e+03  3.590000e+03  4.436000e+03
# 25%       161.000000  8.180080e+05  4.173320e+05  4.018840e+05  4.832630e+05
# 50%       321.000000  1.563715e+06  7.992360e+05  7.594840e+05  9.597440e+05
# 75%       480.000000  2.586258e+06  1.344345e+06  1.264571e+06  1.611588e+06
# max       640.000000  1.106015e+07  5.865078e+06  5.195070e+06  8.227161e+06
#
#        Male_Literate  Female_Literate            SC       Male_SC  \
# count   6.490000e+02     6.490000e+02  6.490000e+02  6.490000e+02
# mean    6.801070e+05     5.144055e+05  3.145731e+05  1.617267e+05
# std     5.903280e+05     4.782859e+05  3.116252e+05  1.604247e+05
# ...

# %%
final_df.to_csv("final_df.csv")

# %%
final_df['District name'].unique().tolist()
# Out:
# ['kupwara',
#  'badgam',
#  'leh(ladakh)',
#  'kargil',
#  'punch',
#  'rajouri',
#  'kathua',
#  'baramula',
#  'bandipore',
#  'srinagar',
#  'ganderbal',
#  'pulwama',
#  'shupiyan',
#  'anantnag',
#  'kulgam',
#  'doda',
#  'ramban',
#  'kishtwar',
#  'udhampur',
#  'reasi',
#  'jammu',
#  'samba',
#  'chamba',
#  'kangra',
#  'lahul and spiti',
#  'kullu',
#  'mandi',
#  'hamirpur',
#  'una',
#  'bilaspur',
#  'solan',
#  'sirmaur',
#  'shimla',
#  'kinnaur',
#  'gurdaspur',
#  'kapurthala',
#  'jalandhar',
#  'hoshiarpur',
#  'shahid bhagat singh nagar',
#  'fatehgarh sahib',
#  'ludhiana',
#  'moga',
#  'firozpur',
#  'muktsar',
#  'faridkot',
#  'bathinda',
#  'mansa',
#  'patiala',
#  'amritsar',
#  'tarn taran',
#  'rupnagar',
#  'sahibzada ajit singh nagar',
#  'sangrur',
#  'barnala',
#  'chandigarh',
#  'uttarkashi',
#  'chamoli',
#  'rudraprayag',
#  'tehri garhwal',
#  'dehradun',
#  'garhwal',
#  'pithoragarh',
#  'bageshwar',
#  'almora',
#  'champawat',
# ...

# %%
final_df['Population'].sum()/10000000
# Out:
# 122.8572236

# %%
1210854977/10000000
# Out:
# 121.0854977

# %%
final_df.columns
# Out:
# Index(['District code', 'State name', 'District name', 'Population', 'Male',
#        'Female', 'Literate', 'Male_Literate', 'Female_Literate', 'SC',
#        ...
#        'Power_Parity_Above_Rs_545000', 'Total_Power_Parity', 'State',
#        'Vehicle', 'Zone', 'Established', 'languages[36]', 'District',
#        'Latitude', 'Longitude'],
#       dtype='object', length=126)

# %%
final_df.groupby('Zone')['Population'].sum().sort_values().plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='Zone'>

# %%
final_df.groupby('Zone')['Male'].sum().sort_values().plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='Zone'>

# %%
# need to change all population values in cr

# %%
gp=final_df.groupby('Vehicle')['Male'].sum().sort_values()
gp=gp.reset_index()
gp['Male']=gp['Male']/10000000
plt.figure(figsize=(12,8))
sn.lineplot(data=gp,x='Vehicle',y='Male')
plt.title('Men Population in Cr')
# Out:
# Text(0.5, 1.0, 'Men Population in Cr')

# %%
gp=final_df.groupby('Vehicle')['Female'].sum().sort_values()
gp=gp.reset_index()
gp['Male']=gp['Female']/10000000
plt.figure(figsize=(12,8))
sn.lineplot(data=gp,x='Vehicle',y='Male')
plt.title('Men Population in Cr')
# Out:
# Text(0.5, 1.0, 'Men Population in Cr')

# %%
final_df[final_df['State name']=='haryana']['Population'].sum()/10000000
# Out:
# 2.5351462

# %%
final_df.head(1)
# Out:
#    District code         State name District name  Population    Male  Female  \
# 0              1  jammu and kashmir       kupwara      870354  474190  396164
#
#    Literate  Male_Literate  Female_Literate    SC  ...  \
# 0    439654         282823           156831  1048  ...
#
#    Power_Parity_Above_Rs_545000  Total_Power_Parity              State  \
# 0                            15                1119  jammu and kashmir
#
#    Vehicle      Zone  Established                          languages[36]  \
# 0       JK  Northern    31-Oct-19  Dogri, English, Hindi, Kashmiri, Urdu
#
#    District  Latitude  Longitude
# 0       NaN       NaN        NaN
#
# [1 rows x 126 columns]

# %%
dist=final_df[final_df['State name']=='uttar pradesh'].groupby('District name')['Population'].sum().reset_index()
dist['Population']=dist['Population']/10000000
sn.barplot(data=dist,x='District name',y='Population')
# Out:
# <AxesSubplot: xlabel='Population', ylabel='District name'>

# %%
dist = final_df[final_df['State name'] == 'uttar pradesh'].groupby('District name')['Population'].sum().reset_index()
dist['Population'] = dist['Population'] / 10000000
dist = dist.sort_values(by='Population')
ax = sn.barplot(data=dist, x='District name', y='Population')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
plt.show()
